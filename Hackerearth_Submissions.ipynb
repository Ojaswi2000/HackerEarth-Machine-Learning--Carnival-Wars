# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use(style="ggplot")
plt.rcParams['figure.figsize']=(10,6)

# %%
train=pd.read_csv('train.csv')
train
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 0     BRAE2NF6JA5GUEXG      37.0  2015-08-22 18:36:12.000                2
# 1     TUNE8SFB6RJN2HSD      38.0  2016-03-27 21:19:13.000               24
# 2     BRAEAR7WZPQGPBZU       9.0  2015-08-18 19:25:22.000              447
# 3     WATDZ2ZQ8JPDHCTJ      50.0  2016-03-28 21:53:01.000               23
# 4     JWSEBUKYQPMBZ3RK       7.0  2016-03-29 22:58:53.000               63
# ...                ...       ...                      ...              ...
# 6363  WATE7VE2D62VEKW8      17.0  2016-03-28 19:55:43.000               24
# 6364  SHOEF9G8Z4ZXF6WE      21.0  2015-02-11 15:09:26.000               55
# 6365  PBXEB9ZQ7HHCFXYG      36.0  2015-11-19 17:29:21.000              358
# 6366  NKCEAGXHRYTNTMG7      27.0  2015-12-08 04:19:33.000              452
# 6367  CAGE53FSAFWZRHFF      11.0  2016-01-20 19:45:35.000               58
#
# ...

# %%
test=pd.read_csv('test.csv')
test
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 0     SCHE4YSTDVPVZVXW      39.0  2016-01-13 07:45:08.000              205
# 1     ACCEGCATKHNRXUHW      49.0  2015-08-23 20:37:05.000                3
# 2     NKCE6GJ5XVJDXNNZ       1.0  2015-11-14 18:12:39.000              183
# 3     NKCEB8BK3ZXDHDHM       8.0  2015-11-21 04:56:19.000              358
# 4     TOPEFDXSAHRNPF94      33.0  2015-05-06 15:09:46.000              167
# ...                ...       ...                      ...              ...
# 3425  BBAE9K7BXFUTDNBK       9.0  2015-08-15 21:17:17.000               58
# 3426  RTRDYPA4PJHCJCGF      30.0  2015-12-04 01:51:47.000              358
# 3427  TUNE8FWQBS7TVVT7      14.0  2016-03-28 20:55:47.000              106
# 3428  NKCEGMUABCRGUZPE       1.0  2015-05-23 07:41:36.000              104
# 3429  RNGE7M92KAQWUBCS       3.0  2015-08-16 22:19:46.000              165
#
# ...

# %%
train.isnull().sum()
# Out:
# Product_id            0
# Stall_no              5
# instock_date          0
# Market_Category       0
# Customer_name       211
# Loyalty_customer      0
# Product_Category      0
# Grade                 0
# Demand                0
# Discount_avail       38
# charges_1           198
# charges_2 (%)       205
# Minimum_price        38
# Maximum_price       343
# Selling_Price        41
# dtype: int64

# %%
train['Selling_Price'].describe()
# Out:
# count     6327.000000
# mean      4563.242592
# std       2979.102408
# min      -6062.470000
# 25%       2450.005280
# 50%       4210.384640
# 75%       6167.643252
# max      22638.325941
# Name: Selling_Price, dtype: float64

# %%
print('Skewness of Selling price is:%f' %(train['Selling_Price'].skew()))
plt.hist(train['Selling_Price'],color='blue')
plt.show()
# Out:
# Skewness of Selling price is:0.850654
# C:\Users\Ojaswi\anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Ojaswi\anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
nulls=pd.DataFrame(train.isnull().sum())
nulls.columns=['Null Values']
nulls
# Out:
#                   Null Values
# Product_id                  0
# Stall_no                    0
# instock_date                0
# Market_Category             0
# Customer_name               0
# Loyalty_customer            0
# Product_Category            0
# Grade                       0
# Demand                      0
# Discount_avail              0
# charges_1                   0
# charges_2 (%)               0
# Minimum_price               0
# Maximum_price               0
# Selling_Price               0

# %%
plt.scatter(train['Stall_no'],train['Selling_Price'])
plt.show()

# %%
train['Stall_no']=train['Stall_no'].interpolate()
train['charges_1']=train['charges_1'].interpolate()
train['charges_2 (%)']=train['charges_2 (%)'].interpolate()
train['Minimum_price']=train['Minimum_price'].interpolate()
train.isnull().sum()
# Out:
# <ipython-input-114-06a669467fb6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Stall_no']=train['Stall_no'].interpolate()
# <ipython-input-114-06a669467fb6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['charges_1']=train['charges_1'].interpolate()
# <ipython-input-114-06a669467fb6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
train
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 0     BRAE2NF6JA5GUEXG      37.0  2015-08-22 18:36:12.000                2
# 1     TUNE8SFB6RJN2HSD      38.0  2016-03-27 21:19:13.000               24
# 2     BRAEAR7WZPQGPBZU       9.0  2015-08-18 19:25:22.000              447
# 3     WATDZ2ZQ8JPDHCTJ      50.0  2016-03-28 21:53:01.000               23
# 4     JWSEBUKYQPMBZ3RK       7.0  2016-03-29 22:58:53.000               63
# ...                ...       ...                      ...              ...
# 6363  WATE7VE2D62VEKW8      17.0  2016-03-28 19:55:43.000               24
# 6364  SHOEF9G8Z4ZXF6WE      21.0  2015-02-11 15:09:26.000               55
# 6365  PBXEB9ZQ7HHCFXYG      36.0  2015-11-19 17:29:21.000              358
# 6366  NKCEAGXHRYTNTMG7      27.0  2015-12-08 04:19:33.000              452
# 6367  CAGE53FSAFWZRHFF      11.0  2016-01-20 19:45:35.000               58
#
# ...

# %%
train.columns
# Out:
# Index(['Product_id', 'Stall_no', 'instock_date', 'Market_Category',
#        'Customer_name', 'Loyalty_customer', 'Product_Category', 'Grade',
#        'Demand', 'Discount_avail', 'charges_1', 'charges_2 (%)',
#        'Minimum_price', 'Maximum_price', 'Selling_Price'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5397 entries, 0 to 6367
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_id        5397 non-null   object
#  1   Stall_no          5397 non-null   float64
#  2   instock_date      5397 non-null   object
#  3   Market_Category   5397 non-null   int64
#  4   Customer_name     5397 non-null   object
#  5   Loyalty_customer  5397 non-null   object
#  6   Product_Category  5397 non-null   object
#  7   Grade             5397 non-null   int64
#  8   Demand            5397 non-null   int64
#  9   Discount_avail    5397 non-null   float64
#  10  charges_1         5397 non-null   float64
#  11  charges_2 (%)     5397 non-null   float64
#  12  Minimum_price     5397 non-null   float64
#  13  Maximum_price     5397 non-null   float64
#  14  Selling_Price     5397 non-null   float64
# dtypes: float64(7), int64(3), object(5)
# memory usage: 674.6+ KB

# %%
def encode(x):
    return 1 if x=='Yes' else 0
train['Loyalty_customer']=train['Loyalty_customer'].apply(encode)
# Out:
# <ipython-input-28-5a894658f1c3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Loyalty_customer']=train['Loyalty_customer'].apply(encode)

# %%
train['Product_Category'].unique()
# Out:
# array(['Fashion', 'Child_care', 'Educational', 'Repair', 'Technology',
#        'Cosmetics', 'Hospitality', 'Organic', 'Pet_care', 'Home_decor'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
train['Product_Category']=le.fit_transform(train['Product_Category'])
# Out:
# <ipython-input-33-ed04d057c2bc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Product_Category']=le.fit_transform(train['Product_Category'])

# %%
train['Product_Category'].unique()
# Out:
# array([3, 0, 2, 8, 9, 1, 5, 6, 7, 4])

# %%
train.columns
# Out:
# Index(['Product_id', 'Stall_no', 'instock_date', 'Market_Category',
#        'Customer_name', 'Loyalty_customer', 'Product_Category', 'Grade',
#        'Demand', 'Discount_avail', 'charges_1', 'charges_2 (%)',
#        'Minimum_price', 'Maximum_price', 'Selling_Price'],
#       dtype='object')

# %%
X=train[['Stall_no','Market_Category','Loyalty_customer', 'Product_Category', 'Grade',
       'Demand', 'Discount_avail', 'charges_1', 'charges_2 (%)',
       'Minimum_price', 'Maximum_price']]
y=train.Selling_Price

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lr.predict(X_test)

# %%
pred
# Out:
# array([ 5617.15112465,  7010.08518846, 11432.64790863, ...,
#         4752.94627373,  9326.48185261,  4379.89861482])

# %%
lr.score(X_test,y_test)
# Out:
# 0.9319592381059171

# %%
test.head(5)
# Out:
#          Product_id  Stall_no             instock_date  Market_Category  \
# 0  SCHE4YSTDVPVZVXW      39.0  2016-01-13 07:45:08.000              205
# 1  ACCEGCATKHNRXUHW      49.0  2015-08-23 20:37:05.000                3
# 2  NKCE6GJ5XVJDXNNZ       1.0  2015-11-14 18:12:39.000              183
# 3  NKCEB8BK3ZXDHDHM       8.0  2015-11-21 04:56:19.000              358
# 4  TOPEFDXSAHRNPF94      33.0  2015-05-06 15:09:46.000              167
#
#   Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 0        Ivanka              No           Fashion      0      90
# 1         Isaak              Yes          Fashion      0      87
# 2      Analiese              No        Technology      2      55
# 3         Rusty              Yes       Child_care      3      86
# 4        Eloise              No        Technology      0      27
#
#    Discount_avail  charges_1  charges_2 (%)  Minimum_price  Maximum_price
# ...

# %%
test.isnull().sum()
# Out:
# Product_id           0
# Stall_no             1
# instock_date         0
# Market_Category      0
# Customer_name       53
# Loyalty_customer     0
# Product_Category     0
# Grade                0
# Demand               0
# Discount_avail       0
# charges_1           36
# charges_2 (%)        5
# Minimum_price       14
# Maximum_price        0
# dtype: int64

# %%
def encode(x):
    return 1 if x=='Yes' else 0
test['Loyalty_customer']=test['Loyalty_customer'].apply(encode)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
test['Product_Category']=le.fit_transform(test['Product_Category'])

# %%
test_data_x=test[['Stall_no','Market_Category','Loyalty_customer', 'Product_Category', 'Grade',
       'Demand', 'Discount_avail', 'charges_1', 'charges_2 (%)',
       'Minimum_price', 'Maximum_price']]

# %%
test_data_x['Stall_no']=test_data_x['Stall_no'].interpolate()

# %%
test_data_x['charges_1']=test_data_x['charges_1'].interpolate()
test_data_x['charges_2 (%)']=test_data_x['charges_2 (%)'].interpolate()
test_data_x['Minimum_price']=test_data_x['Minimum_price'].interpolate()
test_data_x.isnull().sum()
# Out:
# <ipython-input-116-77470f91b30f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data_x['charges_1']=test_data_x['charges_1'].interpolate()
# <ipython-input-116-77470f91b30f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data_x['charges_2 (%)']=test_data_x['charges_2 (%)'].interpolate()
# <ipython-input-116-77470f91b30f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
predictions.shape
# Out:
# (3324,)

# %%
output=pd.DataFrame({'Product_id':test['Product_id'],'Selling_Price':predictions})
output.to_csv("submission1.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-1c542d98bca5> in <module>
# ----> 1 output=pd.DataFrame({'Product_id':test['Product_id'],'Selling_Price':predictions})
#       2 output.to_csv("submission1.csv",index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# ...

# %%
output.head(10)
# Out:
#          Product_id  Selling_Price
# 0  SCHE4YSTDVPVZVXW    3606.581210
# 1  ACCEGCATKHNRXUHW    2395.033650
# 2  NKCE6GJ5XVJDXNNZ   10938.882027
# 3  NKCEB8BK3ZXDHDHM    8949.507973
# 4  TOPEFDXSAHRNPF94    5649.994721
# 5  ACCE558KZHEPZYMG    8825.990371
# 6  ACCEAZCVAMFHDPY7    5165.740407
# 7  NKCDYNY37JPBGBVM    2887.284012
# 8  NKCEY8KWY33FCUYD    7134.550699
# 9  RNGE4YPTQYRECV9J    4554.797290
